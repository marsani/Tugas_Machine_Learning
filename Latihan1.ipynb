# %% [markdown]
# <a href="https://colab.research.google.com/github/alwiemuflich/Tugas_Machine_Learning/blob/main/Latihan1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
path_="/content/drive/My Drive/Machine_Learning/covid_19_indonesia_time_series_all.csv"
dataset=pd.read_csv(path_)
dataset
# Out:
#            Date  ... Growth Factor of New Deaths
# 0      3/1/2020  ...                         NaN
# 1      3/2/2020  ...                        1.00
# 2      3/2/2020  ...                         NaN
# 3      3/2/2020  ...                         NaN
# 4      3/3/2020  ...                        1.00
# ...         ...  ...                         ...
# 6532  9/25/2020  ...                        1.00
# 6533  9/25/2020  ...                        0.00
# 6534  9/25/2020  ...                        2.00
# 6535  9/25/2020  ...                        5.00
# 6536  9/25/2020  ...                        1.67
#
# [6537 rows x 37 columns]

# %%
dataset.head()
# Out:
#        Date  ... Growth Factor of New Deaths
# 0  3/1/2020  ...                         NaN
# 1  3/2/2020  ...                         1.0
# 2  3/2/2020  ...                         NaN
# 3  3/2/2020  ...                         NaN
# 4  3/3/2020  ...                         1.0
#
# [5 rows x 37 columns]

# %%
dataset.shape
# Out:
# (6537, 37)

# %%
dataset.isnull().sum()
# Out:
# Date                              0
# Location ISO Code                 0
# Location                          0
# New Cases                         0
# New Deaths                        0
# New Recovered                     0
# New Active Cases                  0
# Total Cases                       0
# Total Deaths                      0
# Total Recovered                   0
# Total Active Cases                0
# Location Level                    0
# City or Regency                6537
# Province                        208
# Country                           0
# Continent                         0
# Island                          208
# Time Zone                       208
# Special Status                 5579
# Total Regencies                   0
# Total Cities                    182
# Total Districts                   0
# Total Urban Villages            184
# Total Rural Villages            209
# Area (km2)                        0
# Population                        0
# ...

# %%
dataset.max()
# Out:
# Date                                 9/9/2020
# Location ISO Code                         IDN
# Location                       Sumatera Utara
# New Cases                                4823
# New Deaths                                160
# New Recovered                            4343
# New Active Cases                         1533
# Total Cases                            266845
# Total Deaths                            10218
# Total Recovered                        196196
# Total Active Cases                      60431
# Location Level                       Province
# City or Regency                           NaN
# Country                             Indonesia
# Continent                                Asia
# Total Regencies                           416
# Total Cities                               98
# Total Districts                          7230
# Total Urban Villages                     8488
# Total Rural Villages                    74953
# ...

# %%
dataset.describe()
# Out:
#          New Cases  ...  Growth Factor of New Deaths
# count  6537.000000  ...                  5738.000000
# mean     81.538932  ...                     0.976887
# std     319.673572  ...                     0.975189
# min       0.000000  ...                     0.000000
# 25%       1.000000  ...                     1.000000
# 50%       8.000000  ...                     1.000000
# 75%      42.000000  ...                     1.000000
# max    4823.000000  ...                    27.000000
#
# [8 rows x 25 columns]

# %%
dataset.describe().loc['max','New Deaths']
# Out:
# 160.0

# %%
data=dataset.dropna()
data
# Out:
# Empty DataFrame
# Columns: [Date, Location ISO Code, Location, New Cases, New Deaths, New Recovered, New Active Cases, Total Cases, Total Deaths, Total Recovered, Total Active Cases, Location Level, City or Regency, Province, Country, Continent, Island, Time Zone, Special Status, Total Regencies, Total Cities, Total Districts, Total Urban Villages, Total Rural Villages, Area (km2), Population, Population Density, Longitude, Latitude, New Cases per Million, Total Cases per Million, New Deaths per Million, Total Deaths per Million, Case Fatality Rate, Case Recovered Rate, Growth Factor of New Cases, Growth Factor of New Deaths]
# Index: []

# %%
dataset.dropna(axis=0,subset=['Date','Location','New Cases'],inplace=True)
dataset.shape
# Out:
# (6537, 37)

# %%
y=data['Island']
y
# Out:
# Series([], Name: Island, dtype: object)

# %%
fitur=['New Cases','Date']
X=data[fitur]
X
# Out:
# Empty DataFrame
# Columns: [New Cases, Date]
# Index: []

# %%
dataset.describe()['New Cases']['max']
# Out:
# 4823.0

# %%
dataset.min()
# Out:
# Date                            3/1/2020
# Location ISO Code                  ID-AC
# Location                            Aceh
# New Cases                              0
# New Deaths                             0
# New Recovered                          0
# New Active Cases                   -1762
# Total Cases                            1
# Total Deaths                           0
# Total Recovered                        0
# Total Active Cases                   -33
# Location Level                   Country
# City or Regency                      NaN
# Country                        Indonesia
# Continent                           Asia
# Total Regencies                        1
# Total Cities                           1
# Total Districts                       44
# Total Urban Villages                  35
# Total Rural Villages                 275
# Area (km2)                           664
# Population                        648407
# Population Density                  8.59
# ...
